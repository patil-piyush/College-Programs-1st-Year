# %%
import pandas as pd
from matplotlib import pyplot

data = pd.read_csv('CustomerPurchasingBehaviors.csv')
df = pd.DataFrame(data)

# printing entire data set
print(df.to_string())
# Out:
#      user_id  age  annual_income  purchase_amount  loyalty_score region  purchase_frequency
# 0          1   25          45000              200            4.5  North                  12
# 1          2   34          55000              350            7.0  South                  18
# 2          3   45          65000              500            8.0   West                  22
# 3          4   22          30000              150            3.0   East                  10
# 4          5   29          47000              220            4.8  North                  13
# 5          6   41          61000              480            7.8  South                  21
# 6          7   36          54000              400            6.5   West                  19
# 7          8   27          43000              230            4.2   East                  14
# 8          9   50          70000              600            9.0  North                  25
# ...

# %%
import pandas as pd
from matplotlib import pyplot

data = pd.read_csv('CustomerPurchasingBehaviors.csv')
df = pd.DataFrame(data)

# printing first 5 rows
df.head()
# Out:
#    user_id  age  annual_income  purchase_amount  loyalty_score region  \
# 0        1   25          45000              200            4.5  North
# 1        2   34          55000              350            7.0  South
# 2        3   45          65000              500            8.0   West
# 3        4   22          30000              150            3.0   East
# 4        5   29          47000              220            4.8  North
#
#    purchase_frequency
# 0                  12
# 1                  18
# 2                  22
# 3                  10
# 4                  13

# %%
import pandas as pd
from matplotlib import pyplot

data = pd.read_csv('CustomerPurchasingBehaviors.csv')
df = pd.DataFrame(data)

# printing the summary
df.describe()
# Out:
#           user_id         age  annual_income  purchase_amount  loyalty_score  \
# count  238.000000  238.000000     238.000000       238.000000     238.000000
# mean   119.500000   38.676471   57407.563025       425.630252       6.794118
# std     68.848868    9.351118   11403.875717       140.052062       1.899047
# min      1.000000   22.000000   30000.000000       150.000000       3.000000
# 25%     60.250000   31.000000   50000.000000       320.000000       5.500000
# 50%    119.500000   39.000000   59000.000000       440.000000       7.000000
# 75%    178.750000   46.750000   66750.000000       527.500000       8.275000
# max    238.000000   55.000000   75000.000000       640.000000       9.500000
#
#        purchase_frequency
# count          238.000000
# mean            19.798319
# std              4.562884
# min             10.000000
# 25%             17.000000
# 50%             20.000000
# 75%             23.000000
# max             28.000000

# %%
import pandas as pd
from matplotlib import pyplot

data = pd.read_csv('CustomerPurchasingBehaviors.csv')
df = pd.DataFrame(data)

# printing the shape
df.shape
# Out:
# (238, 7)

# %%
import pandas as pd
from matplotlib import pyplot

data = pd.read_csv('CustomerPurchasingBehaviors.csv')
df = pd.DataFrame(data)

# printing the data types of each column
print(df.dtypes)
# Out:
# user_id                 int64
# age                     int64
# annual_income           int64
# purchase_amount         int64
# loyalty_score         float64
# region                 object
# purchase_frequency      int64
# dtype: object

# %%
import pandas as pd
from matplotlib import pyplot as plt

data = pd.read_csv('CustomerPurchasingBehaviors.csv')
df = pd.DataFrame(data)

plt.plot(data.user_id,data.age)
plt.xlabel('ID')
plt.ylabel('Age')
plt.title('Customer Data')
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt

data = pd.read_csv('CustomerPurchasingBehaviors.csv')
df = pd.DataFrame(data)

plt.bar(data.region,data.purchase_frequency)
plt.xlabel('Age')
plt.ylabel('Purchase frequency')
plt.title('Customer Data')
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt

data = pd.read_csv('CustomerPurchasingBehaviors.csv')
df = pd.DataFrame(data)


#creating a histogram of a single column
plt.hist(data.purchase_frequency)
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt

data = pd.read_csv('CustomerPurchasingBehaviors.csv')
df = pd.DataFrame(data)


#creating a histogram of all column
data.hist()
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt

data = pd.read_csv('CustomerPurchasingBehaviors.csv')
df = pd.DataFrame(data.head())

clr = ['yellow', 'red', 'blue', 'green' ]

#creating a pie chart
plt.pie(df.purchase_frequency, labels = df.region, colors = clr, startangle = 0, explode = (0,0,0,0,0))
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt

data = pd.read_csv('CustomerPurchasingBehaviors.csv')
df = pd.DataFrame(data)

plt.scatter(data.user_id,data.age)
plt.xlabel('ID')
plt.ylabel('Age')
plt.title('Customer Data')
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt

data = pd.read_csv('CustomerPurchasingBehaviors.csv')
df = pd.DataFrame(data)


# Create a box plot
plt.figure(figsize=(8,6))
plt.boxplot(data.purchase_frequency)

# Add labels and title
plt.title('Box Plot for Value Column')
plt.xlabel('Values')
plt.ylabel('Distribution')

# Display the plot
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt

data = pd.read_csv('CustomerPurchasingBehaviors.csv')
df = pd.DataFrame(data)

columns_to_plot = ['purchase_frequency', 'age', 'annual_income']
selected_data = data[columns_to_plot]

# Create a box plot
plt.figure(figsize=(8,6))
plt.boxplot(data[columns_to_plot])

# Add labels and title
plt.title('Box Plot for Value Column')
plt.xlabel('Values')
plt.ylabel('Distribution')

# Display the plot
plt.show()
